# %% [markdown]
# # Heart Rate Measurment Using Mobile Phone Camara

# %%
import heartrate as h

# %%
heart = h.HeartRate()

# %%
heart.bpm()
# Out:
# Grayscale image shape: (300, 240, 320)
# [6]
# [0.]
# [6 6]
# [0. 0.]
# [6 6 6]
# [0. 0. 0.]
# [6 6 6 5]
# [0.     0.     0.     0.5625]
# [6 6 6 5 6]
# [0.     0.     0.     0.5625 0.04  ]
# [6 6 6 5 6 6]
# [0.         0.         0.         0.5625     0.04       0.02777778]
# [ 6  6  6  5  6  6 10]
# [ 0.          0.          0.          0.5625      0.04        0.02777778
#  12.75510204]
# [ 6  6  6  5  6  6 10  6]
# [ 0.          0.          0.          0.5625      0.04        0.02777778
#  12.75510204  0.140625  ]
# [ 6  6  6  5  6  6 10  6  7]
# [ 0.          0.          0.          0.5625      0.04        0.02777778
#  12.75510204  0.140625    0.30864198]
# [ 6  6  6  5  6  6 10  6  7 10]
# [ 0.          0.          0.          0.5625      0.04        0.02777778
#  12.75510204  0.140625    0.30864198 10.24      ]
# [ 6  6  6  5  6  6 10  6  7 10  5]
# [ 0.          0.          0.          0.5625      0.04        0.02777778
# ...
